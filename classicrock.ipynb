# %% [markdown]
# ## Classic Rock Songs Project
#
# Jose Guzman

# %% [markdown]
# Section 1-Load - Read from a data file into a pandas DataFrame.

# %%
import pandas as pd
import chardet

with open('classic-rock-song-list.csv','rb') as f:
    result  = chardet.detect(f.read())

songs = pd.read_csv('classic-rock-song-list.csv', encoding=result['encoding'])

songs
# Out:
#                                        Song Clean ARTIST CLEAN Release Year  \
# 0                                Caught Up in You  .38 Special         1982
# 1                                    Fantasy Girl  .38 Special          NaN
# 2                                 Hold On Loosely  .38 Special         1981
# 3                          Rockin' Into the Night  .38 Special         1980
# 4                               Art For Arts Sake         10cc         1975
# ...                                           ...          ...          ...
# 2224                      She Loves My Automobile       ZZ Top          NaN
# 2225                            Tube Snake Boogie       ZZ Top         1981
# 2226                                         Tush       ZZ Top         1975
# 2227                                   TV Dinners       ZZ Top         1983
# 2228  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO       ZZ Top         1973
#
# ...

# %% [markdown]
# ## Section 2-View - Display the first 5 rows and the last 5 rows.

# %%
import pandas as pd

songs = pd.read_csv('classic-rock-song-list.csv', index_col=0)

pd.set_option('display.precision', 2)

first_5_rows = songs.head(5)

last_5_rows = songs.tail(5)

result = pd.concat([first_5_rows, last_5_rows])

print(result)
# Out:
#                                             ARTIST CLEAN Release Year  \
# Song Clean
# Caught Up in You                             .38 Special         1982
# Fantasy Girl                                 .38 Special          NaN
# Hold On Loosely                              .38 Special         1981
# Rockin' Into the Night                       .38 Special         1980
# Art For Arts Sake                                   10cc         1975
# She Loves My Automobile                           ZZ Top          NaN
# Tube Snake Boogie                                 ZZ Top         1981
# Tush                                              ZZ Top         1975
# TV Dinners                                        ZZ Top         1983
# WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO       ZZ Top         1973
#
#                                                                                       COMBINED  \
# Song Clean
# ...

# %% [markdown]
# ## Section 3-Describe: Use the DataFrame describe() function to calculate basic descriptive statistics for all numeric columns.

# %%
import pandas as pd

songs = pd.read_csv('classic-rock-song-list.csv', index_col=0)

pd.set_option('display.precision', 2)

songs.describe()
# Out:
#        First?    Year?  PlayCount      F*G
# count  2229.0  2229.00    2229.00  2229.00
# mean      1.0     0.74      16.88    15.05
# std       0.0     0.44      25.31    25.29
# min       1.0     0.00       0.00     0.00
# 25%       1.0     0.00       1.00     0.00
# 50%       1.0     1.00       4.00     3.00
# 75%       1.0     1.00      21.00    18.00
# max       1.0     1.00     142.00   142.00

# %% [markdown]
# ## Section 4-Series: Use the Series method describe() to calculate the descriptive stats for all category/text columns.

# %%
import pandas as pd

songs = pd.read_csv('classic-rock-song-list.csv', index_col=0)

pd.set_option('display.precision', 2)

songs.describe(include='object')
# Out:
#        ARTIST CLEAN Release Year                         COMBINED
# count          2229         1653                             2229
# unique          475           56                             2229
# top     The Beatles         1973  Caught Up in You by .38 Special
# freq            100          104                                1

# %% [markdown]
# ## Section 5-Unique: Use the Series method unique() to get unique category values.

# %%
import pandas as pd

df = pd.read_csv('classic-rock-song-list.csv')

columns_of_interest = ['Song_Clean', 'ARTIST_CLEAN', 'Release_Year', 'COMBINED', 'First?', 'Year?', 'PlayCount', 'F*G']

for col in columns_of_interest:
    unique_values = df[col].unique()
    print(f"Unique values for {col}: {unique_values}")
# Out:
# Unique values for Song_Clean: ['Caught Up in You' 'Fantasy Girl' 'Hold On Loosely' ... 'Tush'
#  'TV Dinners' "WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO"]
# Unique values for ARTIST_CLEAN: ['.38 Special' '10cc' '3 Doors Down' '4 Non Blondes' 'a-ha' 'AC/DC' 'Ace'
#  'Adelitas Way' 'Aerosmith' 'Alanis Morissette' 'Alannah Myles'
#  'Aldo Nova' 'Alice Cooper' 'Alice In Chains' 'Allman Brothers Band'
#  'America' 'Animals II' 'Ann Wilson' 'April Wine' 'Argent' 'Arlo Guthrie'
#  'Artful Dodger' 'Asia' 'Atlanta Rhythm Section' 'Audioslave' 'Autograph'
#  'Axe' 'Bachman-Turner Overdrive' 'Bad Company' 'Bad English' 'Badfinger'
#  'Baton Rouge' 'Beastie Boys' 'Beck' 'Big Country' 'Bill Haley'
#  'Bill Withers' 'Billy Idol' 'Billy Joel' 'Billy Rankin' 'Billy Squier'
#  'Billy Thorpe' 'Black Sabbath' 'Blackfoot' 'Blind Faith' 'Blind Melon'
#  'Blink-182' 'Blondie' 'Blue Oyster Cult' 'Blur' 'Bob Dylan' 'Bob Marley'
#  'Bob Seger' 'Bob Welch' 'Bon Jovi' 'Bonham' "Booker T. and the MG's"
# ...

# %% [markdown]
# ## Section 6-Histograms: Use the DataFrame's hist() function to create a histogram for each numerical column.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'df'
df = pd.read_csv('classic-rock-song-list.csv')

columns_of_interest = ['Song_Clean', 'ARTIST_CLEAN', 'Release_Year', 'COMBINED', 'First?', 'Year?', 'PlayCount', 'F*G']

# Filter out the numerical columns
numerical_columns = df[columns_of_interest].select_dtypes(include=['int64', 'float64']).columns

for col in numerical_columns:
    df[col].hist()
    plt.title(col)
    plt.show()

# %% [markdown]
# ## Section 7-List: Get some of your information into a list. Process each item in the list (use for or comprehensions as you like).

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df'
df = pd.read_csv('classic-rock-song-list.csv')

columns_of_interest = ['Song_Clean', 'ARTIST_CLEAN', 'Release_Year', 'COMBINED', 'First?', 'Year?', 'PlayCount', 'F*G']

# Get the first row of your DataFrame into a list
row_data = df.loc[0, columns_of_interest].tolist()

# Process each item in the list
for item in row_data:
    print(f"Processing item: {item}")
# Out:
# Processing item: Caught Up in You
# Processing item: .38 Special
# Processing item: 1982
# Processing item: Caught Up in You by .38 Special
# Processing item: 1
# Processing item: 1
# Processing item: 82
# Processing item: 82

# %% [markdown]
# ## Section 8-Filter: Use filter() to show only part of the information.

# %%
import pandas as pd

df = pd.read_csv('classic-rock-song-list.csv')

columns_of_interest = ['Song_Clean', 'ARTIST_CLEAN']

# Use filter() to select only the columns of interest
filtered_df = df.filter(items=columns_of_interest)

print(filtered_df)
# Out:
#                                        Song_Clean ARTIST_CLEAN
# 0                                Caught Up in You  .38 Special
# 1                                    Fantasy Girl  .38 Special
# 2                                 Hold On Loosely  .38 Special
# 3                          Rockin' Into the Night  .38 Special
# 4                               Art For Arts Sake         10cc
# ...                                           ...          ...
# 2224                      She Loves My Automobile       ZZ Top
# 2225                            Tube Snake Boogie       ZZ Top
# 2226                                         Tush       ZZ Top
# 2227                                   TV Dinners       ZZ Top
# 2228  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO       ZZ Top
#
# [2229 rows x 2 columns]

# %% [markdown]
# ## Section 9-Map: Use map() to transform some of the data.

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df'
df = pd.read_csv('classic-rock-song-list.csv')

columns_of_interest = ['Song_Clean', 'ARTIST_CLEAN', 'Release_Year', 'COMBINED', 'First?', 'Year?', 'PlayCount', 'F*G']

# Convert 'Release_Year' to numeric, errors='coerce' will replace non-numeric values with NaN
df['Release_Year'] = pd.to_numeric(df['Release_Year'], errors='coerce')

# Use map() to transform the 'Release_Year' column
df['Release_Year'] = df['Release_Year'].map(lambda x: x if x >= 2000 else None)

print(df[columns_of_interest])
# Out:
#                                        Song_Clean ARTIST_CLEAN  Release_Year  \
# 0                                Caught Up in You  .38 Special           NaN
# 1                                    Fantasy Girl  .38 Special           NaN
# 2                                 Hold On Loosely  .38 Special           NaN
# 3                          Rockin' Into the Night  .38 Special           NaN
# 4                               Art For Arts Sake         10cc           NaN
# ...                                           ...          ...           ...
# 2224                      She Loves My Automobile       ZZ Top           NaN
# 2225                            Tube Snake Boogie       ZZ Top           NaN
# 2226                                         Tush       ZZ Top           NaN
# 2227                                   TV Dinners       ZZ Top           NaN
# 2228  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO       ZZ Top           NaN
#
# ...

# %% [markdown]
# ## Tell a Story - Which was the most played Classic Rock Song from the CSV list?

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df'
df = pd.read_csv('classic-rock-song-list.csv')

# Use idxmax() to find the index of the row with the highest 'PlayCount'
most_played_index = df['PlayCount'].idxmax()

# Get the 'Song_Clean' and 'ARTIST_CLEAN' of the most played song
most_played_song = df.loc[most_played_index, 'Song_Clean']
most_played_artist = df.loc[most_played_index, 'ARTIST_CLEAN']

print(f"The most played song is '{most_played_song}' by {most_played_artist}.")
# Out:
# The most played song is 'Dream On' by Aerosmith.
